# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasvx273/Python_openpyxl_LPS/blob/main/Python_openpyxl_intro02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Como utilizar Excel e Python**
#
# **Módulo openpyxl**
#
# # atualizando o pacote
# !pip install -U openpyxl -q

# %%
# !pip install -U openpyxl -q

# importando a lib
from openpyxl import Workbook

# criando o workbook/ planilha
workbook = Workbook()

# selecionando a aba
sheet = workbook.active

# para salvar as alterações, utilizar o comando abaixo
workbook.save(filename='helloworld.xlsx')

# %% [markdown]
# Formas de acessar a celula:

# %%
# acesando as células
sheet['F10'].value

# %% [markdown]
# ou:

# %%
# acessando as células
sheet.cell(row=10, column=6).value

# %% [markdown]
# Caregar uma Planilha:
#
# from openpyxl import load_workbook
# workbook = load_workbook(filename='controle_da_empresa.xlsx')

# %%
# !pip install -U openpyxl -q

# carregando uma planilha
from openpyxl import load_workbook

# carregando o arquivo
workbook = load_workbook(filename='/content/Teste Python.xlsx')

# verificando as abas
workbook.sheetnames #Ou::: sheet.title
# Out:
# ['1640674804006']

# %%
workbook.save(filename='teste1.xlsx')

# %%
sheet = workbook.active
x = 'F2'

sheet[x] = '= C2-D2'
sheet["F2"].value
# Out:
# '= C2-D2'

# %% [markdown]
# Comando::: **sheet.max_row** (Traz o número máximo de linhas)
#
#
# Comando::: **sheet.max_column** (Traz o número máximo de colunas)

# %%
max_linha = sheet.max_row
max_coluna = sheet.max_column
row_x = 2
column = 6
y = "F"
z = str(row_x)
x = y + z
print(x)
print(type(x))

for n in range(1,max_linha-1):
    sheet[x] = "65"
    row_x += 1

#mostrar valores de linhas
for value in sheet.iter_rows(min_row=1,
                           max_row=5,
                           min_col=1,
                           max_col=6,
                           values_only=True):
  print(value)
# Out:
# F2
# <class 'str'>
# ('vehicleTypeCodeName', 'startHour', 'endHour', 'duration', 'activityCodeName', None)
# ('2 - Trator John Deere 8260', datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', '65')
# ('2 - Trator John Deere 8260', datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', '65')
# ('2 - Trator John Deere 8260', datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', '65')
# ('2 - Trator John Deere 8260', datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', '65')

# %%
workbook.save(filename='teste1.xlsx')

# %% [markdown]
# # Iterando os dados excel

# %%
# carregando uma planilha
from openpyxl import load_workbook

workbook = load_workbook(filename='/content/Teste Python.xlsx')

# verificando as abas
sheet = workbook["1640674804006"]  # Também poderia ser::: workbook.active

# %%
# iterando sobre os dados
for value in sheet.iter_rows(min_row=2, max_row=sheet.max_row,min_col=2,max_col=sheet.max_column,values_only=True):
  print(value)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(0, 3, 1), '833 - Deslocamento')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(0, 1, 17), '833 - Deslocamento')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(0, 1, 30), '8332 - Parada em Deslocamento')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 0, 30), '0 - Não selecionada/Not confirmed')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 2, 22), '150 - Subsolagem')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 21, 3), '150 - Subsolagem')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 11, 2), '218 - Troca de Turno')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 8, 8), '231 - Regulagem de Implemento')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 10, 17), '264 - Check list')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 1, 13), '832 - Manobra (832)')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 0, 50), '832 - Manobra (832)')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 0, 17), '832 - Manobra (832)')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 1), '833 - Deslocamento')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(0, 3, 18), '833 - Deslocamento')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 4, 36), '0 - Não selecionada/Not confirmed')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 13, 9), '150 - Subsolagem')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 22, 6), '229 - 229-Manutenção Corretiva Implemento')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 8, 55), '229 - 229-Manutenção Corretiva Implemento')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 2, 50), '231 - Regulagem de Implemento')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 1, 20), '832 - Manobra (832)')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 1, 51), '833 - Deslocamento')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 2, 20), '833 - Deslocamento')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 2, 54), '8332 - Parada em Deslocamento')
# (datetime.time(0, 0), datetime.time(1, 0), datetime.time(0,

# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(0, 1, 26), '833 - Deslocamento')
# (datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(4, 0), datetime.time(5, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(5, 0), datetime.time(6, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(6, 0), datetime.time(7, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(7, 0), datetime.time(8, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(8, 0), datetime.time(9, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(9, 0), datetime.time(10, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(10, 0), datetime.time(11, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(11, 0), datetime.time(12, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(12, 0), datetime.time(13, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(13, 0), datetime.time(14, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(14, 0), datetime.time(15, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(15, 0), datetime.time(16, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(16, 0), datetime.time(17, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(17, 0), datetime.time(18, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(18, 0), datetime.time(19, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(19, 0), datetime.time(20, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(20, 0), datetime.time(21, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(4, 0), datetime.time(5, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(5, 0), datetime.time(6, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(6, 0), datetime.time(7, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(7, 0), datetime.time(8, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(8, 0), datetime.time(9, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(9, 0), datetime.time(10, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(10, 0), datetime.time(11, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(11, 0), datetime.time(12, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(12, 0), datetime.time(13, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(13, 0), datetime.time(14, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(14, 0), datetime.time(15, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(15, 0), datetime.time(16, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(16, 0), datetime.time(17, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(17, 0), datetime.time(18, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(18, 0), datetime.time(19, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(19, 0), datetime.time(20, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(20, 0), datetime.time(21, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown')
# (datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(4, 0), datetime.time(5, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(5, 0), datetime.time(6, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(6, 0), datetime.time(7, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(7, 0), datetime.time(8, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(8, 0), datetime.time(9, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(9, 0), datetime.time(10, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(10, 0), datetime.time(11, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(11, 0), datetime.time(12, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(12, 0), datetime.time(13, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(13, 0), datetime.time(14, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(14, 0), datetime.time(15, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(15, 0), datetime.time(16, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(16, 0), datetime.time(17, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(17, 0), datetime.time(18, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(18, 0), datetime.time(19, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(19, 0), datetime.time(20, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(20, 0), datetime.time(21, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(4, 0), datetime.time(5, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(5, 0), datetime.time(6, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(6, 0), datetime.time(7, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(7, 0), datetime.time(8, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(8, 0), datetime.time(9, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(9, 0), datetime.time(10, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(10, 0), datetime.time(11, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(11, 0), datetime.time(12, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(12, 0), datetime.time(13, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(13, 0), datetime.time(14, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(14, 0), datetime.time(15, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(15, 0), datetime.time(16, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(16, 0), datetime.time(17, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(17, 0), datetime.time(18, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(18, 0), datetime.time(19, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(19, 0), datetime.time(20, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(20, 0), datetime.time(21, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(1, 0), 'IND - Indeterminado/Unknown')
# (datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(4, 0), datetime.time(5, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(5, 0), datetime.time(6, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(6, 0), datetime.time(7, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(7, 0), datetime.time(8, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(8, 0), datetime.time(9, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(9, 0), datetime.time(10, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(10, 0), datetime.time(11, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(11, 0), datetime.time(12, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(12, 0), datetime.time(13, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(13, 0), datetime.time(14, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(14, 0), datetime.time(15, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(15, 0), datetime.time(16, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(16, 0), datetime.time(17, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(17, 0), datetime.time(18, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(18, 0), datetime.time(19, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(19, 0), datetime.time(20, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(20, 0), datetime.time(21, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(21, 0), datetime.time(22, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(22, 0), datetime.time(23, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')
# (datetime.time(23, 0), datetime.time(0, 0), datetime.time(1, 0), '0 - Não selecionada/Not confirmed')

# %%
#Agora iremos criar um índice na coluna F para nortear os dados:
max_linha = sheet.max_row
row_x = int(1)
x = str("F" + str(row_x))


for n in range(2, max_linha+1):
    row_x += 1
    x = str("F" + str(row_x))
    sheet[x].value = x

sheet["F1"].value = "Índice"

#Iterar dados para ver se indice foi criado
for value in sheet.iter_rows(min_row=1,
                           max_row=5,
                           min_col=1,
                           max_col=6,
                           values_only=True):
  print(value)
# Out:
# ('vehicleTypeCodeName', 'startHour', 'endHour', 'duration', 'activityCodeName', 'Índice')
# ('2 - Trator John Deere 8260', datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F2')
# ('2 - Trator John Deere 8260', datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F3')
# ('2 - Trator John Deere 8260', datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F4')
# ('2 - Trator John Deere 8260', datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F5')

# %% [markdown]
# # Convertendo a planilha em um Data Frame

# %%
#Criação de um dicionário seguindo o índice criado anteriormente:
indice = {}

for celula in sheet.iter_rows(min_row=2,max_col=6,
                              values_only=True):
  
  chave = celula[5]
  sumario = {
      "type": celula[0],
      "start": celula[1],
      "end": celula[2],
      "duration": celula[3],
      "activity": celula[4]
  }
  indice[chave] = sumario
  ### utilizado 3 variaveis de dicionário para criação deste: indice, sumario e chave

# %% [markdown]
# **df = pd.DataFrame.from_dict(products, orient="index")**

# %%
# Agora literalmente passando os dados para data frame via pandas
import pandas as pd
df = pd.DataFrame.from_dict(indice, orient="index")
df
# Out:
#                                                     type  ...                           activity
# F2                            2 - Trator John Deere 8260  ...        OFF - Desligamento/Shutdown
# F3                            2 - Trator John Deere 8260  ...        OFF - Desligamento/Shutdown
# F4                            2 - Trator John Deere 8260  ...        OFF - Desligamento/Shutdown
# F5                            2 - Trator John Deere 8260  ...        OFF - Desligamento/Shutdown
# F6                            2 - Trator John Deere 8260  ...        OFF - Desligamento/Shutdown
# ...                                                  ...  ...                                ...
# F10436  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10437  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10438  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10439  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10440  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
#
# [10439 rows x 5 columns]

# %%
print(df.head(5),'\n\n\'')
print(df.tail(5))
# Out:
#                           type     start  ...  duration                     activity
# F2  2 - Trator John Deere 8260  00:00:00  ...  01:00:00  OFF - Desligamento/Shutdown
# F3  2 - Trator John Deere 8260  01:00:00  ...  01:00:00  OFF - Desligamento/Shutdown
# F4  2 - Trator John Deere 8260  02:00:00  ...  01:00:00  OFF - Desligamento/Shutdown
# F5  2 - Trator John Deere 8260  03:00:00  ...  01:00:00  OFF - Desligamento/Shutdown
# F6  2 - Trator John Deere 8260  04:00:00  ...  01:00:00  OFF - Desligamento/Shutdown
#
# [5 rows x 5 columns]
#
# '
#                                                     type  ...                           activity
# F10436  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10437  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10438  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10439  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
# F10440  8 - Trator Case 260 (Remap. 290cv) / Case MX 315  ...  0 - Não selecionada/Not confirmed
#
# [5 rows x 5 columns]

# %%
df.loc["F22"]
# Out:
# type         2 - Trator John Deere 8260
# start                          20:00:00
# end                            21:00:00
# duration                       01:00:00
# activity    OFF - Desligamento/Shutdown
# Name: F22, dtype: object

# %% [markdown]
# **Adicionando dados, abas, colunas e linhas**

# %%
sheet = workbook.active

cell = sheet["G1"]

cell.value = "Teste G1"

for n in sheet.iter_rows(min_row=1,max_row=2,values_only=True):
  print(n)
# Out:
# ('vehicleTypeCodeName', 'startHour', 'endHour', 'duration', 'activityCodeName', 'Índice', 'Teste G1')
# ('2 - Trator John Deere 8260', datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F2', None)

# %%
#Uma espécie de SHAPE da sheet:
sheet.dimensions

#Comando para adicionar/remover colunas/linhas
sheet.insert_cols(idx=1)
sheet.insert_rows(idx=1)
sheet.delete_cols(idx=3, amount=3)
sheet.delete_rows(idx=3, amount=3)

#Comando genérico para imprimir linhas
print_rows()

# %%
#Criação de abas, o número após a virgua é a posição dessa nova aba, segue escala Python:
new_sheet = workbook.create_sheet("Teste de criação", 1)
workbook.sheetnames
# Out:
# ['1640674804006', 'Teste de criação', 'Teste de criação1']

# %%
#Deletar uma aba:
workbook.remove(workbook["Teste de criação"])
workbook.sheetnames

#é possível copiar pelo comando::
workbook.copy_worksheet(workbook["1640674804006"])
# Out:
# <Worksheet "1640674804006 Copy">

# %%
#Deixando a planilha em ordem :)
workbook.remove(workbook["1640674804006 Copy"])
workbook.sheetnames
# Out:
# ['1640674804006']

# %% [markdown]
# **Navegação**

# %%
# Para consultar as abas a escolha delas sera em escala inical ZERO pelo Python [0] pois..:
# ..: está como lista.

sheet = workbook.sheetnames[0]
# nesse caso acima, selecionei a primeira e única aba: "1640674804006"

sheet = workbook["1640674804006"]
sheet.title = "Teste"
print(sheet.title)
sheet.title = "1640674804006"
print(sheet.title)
# Out:
# Teste
# 1640674804006

# %% [markdown]
# **Filtros**

# %%
#adicionando um filtro automatico (Nesse caso aproveitei o comando dimensions):
sheet.auto_filter.ref = sheet.dimensions #Poderia ser ex: "A1:C10"

# %%
#Importante biblioteca de formulas
from openpyxl.utils import FORMULAE

#Verificando formulas
FORMULAE
# Out:
# frozenset({'ABS',
#            'ACCRINT',
#            'ACCRINTM',
#            'ACOS',
#            'ACOSH',
#            'AMORDEGRC',
#            'AMORLINC',
#            'AND',
#            'AREAS',
#            'ASC',
#            'ASIN',
#            'ASINH',
#            'ATAN',
#            'ATAN2',
#            'ATANH',
#            'AVEDEV',
#            'AVERAGE',
#            'AVERAGEA',
#            'AVERAGEIF',
#            'AVERAGEIFS',
#            'BAHTTEXT',
#            'BESSELI',
#            'BESSELJ',
#            'BESSELK',
#            'BESSELY',
#            'BETADIST',
#            'BETAINV',
#            'BIN2DEC',
#            'BIN2HEX',
#            'BIN2OCT',
#            'BINOMDIST',
#            'CEILING',
#            'CELL',
#            'CHAR',
#            'CHIDIST',
#            'CHIINV',
#            'CHITEST',
#            'CHOOSE',
#            'CLEAN',
#            'CODE',
#            'COLUMN',
#            'COLUMNS',
#            'COMBIN',
#            'COMPLEX',
#            'CONCATENATE',
#            'CONFIDENCE',
#            'CONVERT',
#            'CORREL',
#            'COS',
#            'COSH',
#            'COUNT',
#            'COUNTA',
#            'COUNTBLANK',
#            'COUNTIF',
#            'COUNTIFS',
#            'COUPDAYBS',
#            'COUPDAYS',
#            'COUPDAYSNC',
#            'COUPNCD',
#            'COUPNUM',
#            'COUPPCD',
#            'COVAR',
#            'CRITBINOM',
#            'CUBEKPIMEMBER',
#            'CUBEMEMBER',
#            'CUBEMEMBERPROPERTY',
#            'CUBERANKEDMEMBER',
#            'CUBESET',
#            'CUBESETCOUNT',
#            'CUBEVALUE',
#            'CUMIPMT',
#            'CUMPRINC',
#            'DATE',
#            'DATEDIF',
#            'DATEVALUE',
#            'DAVERAGE',
#            'DAY',
#            'DAYS360',
#            'DB',
#            'DCOUNT',
#            'DCOUNTA',
#            'DDB',
#            'DEC2BIN',
#            'DEC2HEX',
#            'DEC2OCT',
#            'DEGREES',
#            'DELTA',
#            'DEVSQ',
#            'DGET',
#            'DISC',
#            'DMAX',
#            'DMIN',
#            'DOLLAR',
#            'DOLLARDE',
#            'DOLLARFR',
#            'DPRODUCT',
#            'DSTDEV',
#            'DSTDEVP',
#            'DSUM',
#            'DURATION',
#            'DVAR',
#            'DVARP',
#            'ECMA.CEILING',
#            'EDATE',
#            'EFFECT',
#            'EOMONTH',
#            'ERF',
#            'ERFC',
#            'ERROR.TYPE',
#            'EVEN',
#            'EXACT',
#            'EXP',
#            'EXPONDIST',
#            'FACT',
#            'FACTDOUBLE',
#            'FALSE',
#            'FDIST',
#            'FIND',
#            'FINDB',
#            'FINV',
#            'FISHER',
#            'FISHERINV',
#            'FIXED',
#            'FLOOR',
#            'FORECAST',
#            'FREQUENCY',
#            'FTEST',
#            'FV',
#            'FVSCHEDULE',
#            'GAMMADIST',
#            'GAMMAINV',
#            'GAMMALN',
#            'GCD',
#            'GEOMEAN',
#            'GESTEP',
#            'GETPIVOTDATA',
#            'GROWTH',
#            'HARMEAN',
#            'HEX2BIN',
#            'HEX2DEC',
#            'HEX2OCT',
#            'HLOOKUP',
#            'HOUR',
#            'HYPERLINK',
#            'HYPGEOMDIST',
#            'IF',
#            'IFERROR',
#            'IMABS',
#            'IMAGINARY',
#            'IMARGUMENT',
#            'IMCONJUGATE',
#            'IMCOS',
#            'IMDIV',
#            'IMEXP',
#            'IMLN',
#            'IMLOG10',
#            'IMLOG2',
#            'IMPOWER',
#            'IMPRODUCT',
#            'IMREAL',
#            'IMSIN',
#            'IMSQRT',
#            'IMSUB',
#            'IMSUM',
#            'INDEX',
#            'INDIRECT',
#            'INFO',
#            'INT',
#            'INTERCEPT',
#            'INTRATE',
#            'IPMT',
#            'IRR',
#            'ISBLANK',
#            'ISERR',
#            'ISERROR',
#            'ISEVEN',
#            'ISLOGICAL',
#            'ISNA',
#            'ISNONTEXT',
#            'ISNUMBER',
#            'ISO.CEILING',
#            'ISODD',
#            'ISPMT',
#            'ISREF',
#            'ISTEXT',
#            'JIS',
#            'KURT',
#            'LARGE',
#            'LCM',
#            'LEFT',
#            'LEFTB',
#            'LEN',
#            'LENB',
#            'LINEST',
#            'LN',
#            'LOG',
#            'LOG10',
#            'LOGEST',
#            'LOGINV',
#            'LOGNORMDIST',
#            'LOOKUP',
#            'LOWER',
#            'MATCH',
#            'MAX',
#            'MAXA',
#            'MDETERM',
#            'MDURATION',
#            'MEDIAN',
#            'MID',
#            'MIDB',
#            'MIN',
#            'MINA',
#            'MINUTE',
#            'MINVERSE',
#            'MIRR',
#            'MMULT',
#            'MOD',
#            'MODE',
#            'MONTH',
#            'MROUND',
#            'MULTINOMIAL',
#            'N',
#            'NA',
#            'NEGBINOMDIST',
#            'NETWORKDAYS',
#            'NETWORKDAYS.INTL',
#            'NOMINAL',
#            'NORMDIST',
#            'NORMINV',
#            'NORMSDIST',
#            'NORMSINV',
#            'NOT',
#            'NOW',
#            'NPER',
#            'NPV',
#            'OCT2BIN',
#            'OCT2DEC',
#            'OCT2HEX',
#            'ODD',
#            'ODDFPRICE',
#            'ODDFYIELD',
#            'ODDLPRICE',
#            'ODDLYIELD',
#            'OFFSET',
#            'OR',
#            'PEARSON',
#            'PERCENTILE',
#            'PERCENTRANK',
#            'PERMUT',
#            'PHONETIC',
#            'PI',
#            'PMT',
#            'POISSON',
#            'POWER',
#            'PPMT',
#            'PRICE',
#            'PRICEDISC',
#            'PRICEMAT',
#            'PROB',
#            'PRODUCT',
#            'PROPER',
#            'PV',
#            'QUARTILE',
#            'QUOTIENT',
#            'RADIANS',
#            'RAND',
#            'RANDBETWEEN',
#            'RANK',
#            'RATE',
#            'RECEIVED',
#            'REPLACE',
#            'REPLACEB',
#            'REPT',
#            'RIGHT',
#            'RIGHTB',
#            'ROMAN',
#            'ROUND',
#            'ROUNDDOWN',
#            'ROUNDUP',
#            'ROW',
#            'ROWS',
#            'RSQ',
#            'RTD',
#            'SEARCH',
#            'SEARCHB',
#            'SECOND',
#            'SERIESSUM',
#            'SIGN',
#            'SIN',
#            'SINH',
#            'SKEW',
#            'SLN',
#            'SLOPE',
#            'SMALL',
#            'SQRT',
#            'SQRTPI',
#            'STANDARDIZE',
#            'STDEV STDEVA',
#            'STDEVP',
#            'STDEVPA STEYX',
#            'SUBSTITUTE',
#            'SUBTOTAL',
#            'SUM',
#            'SUMIF',
#            'SUMIFS',
#            'SUMPRODUCT',
#            'SUMSQ',
#            'SUMX2MY2',
#            'SUMX2PY2',
#            'SUMXMY2',
#            'SYD',
#            'T',
#            'TAN',
#            'TANH',
#            'TBILLEQ',
#            'TBILLPRICE',
#            'TBILLYIELD',
#            'TDIST',
#            'TEXT',
#            'TIME',
#            'TIMEVALUE',
#            'TINV',
#            'TODAY',
#            'TRANSPOSE',
#            'TREND',
#            'TRIM',
#            'TRIMMEAN',
#            'TRUE ADDRESS',
#            'TRUNC',
#            'TTEST',
#            'TYPE',
#            'UPPER',
#            'VALUE',
#            'VAR',
#            'VARA',
#            'VARP',
#            'VARPA',
#            'VDB',
#            'VLOOKUP',
#            'WEEKDAY',
#            'WEEKNUM',
#            'WEIBULL',
#            'WORKDAY ',
#            'WORKDAY.INTL',
#            'XIRR',
#            'XNPV',
#            'YEAR',
#            'YEARFRAC',
#            'YIELD',
#            'YIELDDISC',
#            'YIELDMAT',
#            'ZTEST'})

# %%
for value in sheet.iter_rows(min_row=1,
                           max_row=5,
                           min_col=1,
                           max_col=6,
                           values_only=True):
  print(value)
# Out:
# ('vehicleTypeCodeName', 'startHour', 'endHour', 'duration', 'activityCodeName', 'Índice')
# ('2 - Trator John Deere 8260', datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F2')
# ('2 - Trator John Deere 8260', datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F3')
# ('2 - Trator John Deere 8260', datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F4')
# ('2 - Trator John Deere 8260', datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F5')

# %% [markdown]
# **Fórmulas**

# %%
#adicionando uma formula
sheet["G1"] = "Soma Start + End"
sheet["G2"] = "=SUM(B2:C2)"

# %%
for value in sheet.iter_rows(min_row=1,
                           max_row=5,
                           min_col=1,
                           max_col=7,
                           values_only=True):
  print(value)
# Out:
# ('vehicleTypeCodeName', 'startHour', 'endHour', 'duration', 'activityCodeName', 'Índice', 'Soma Start + End')
# ('2 - Trator John Deere 8260', datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F2', '=SUM(B2:C2)')
# ('2 - Trator John Deere 8260', datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F3', None)
# ('2 - Trator John Deere 8260', datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F4', None)
# ('2 - Trator John Deere 8260', datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F5', None)

# %%
#Tentativa de reproduzir formula coluna G em escala:::
x = 1
y = "SUM(B"+str(x)+":C"+str(x)+")"


for cell in sheet.iter_rows(min_row=2,values_only=True):
  x += 1
  y = "=SUM(B"+str(x)+":C"+str(x)+")"
  sheet["G"+str(x)] = y


for value in sheet.iter_rows(min_row=1,
                           max_row=5,
                           min_col=1,
                           max_col=7,
                           values_only=True):
  print(value)
# Out:
# ('vehicleTypeCodeName', 'startHour', 'endHour', 'duration', 'activityCodeName', 'Índice', 'Soma Start + End')
# ('2 - Trator John Deere 8260', datetime.time(0, 0), datetime.time(1, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F2', '=SUM(B2:C2)')
# ('2 - Trator John Deere 8260', datetime.time(1, 0), datetime.time(2, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F3', '=SUM(B3:C3)')
# ('2 - Trator John Deere 8260', datetime.time(2, 0), datetime.time(3, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F4', '=SUM(B4:C4)')
# ('2 - Trator John Deere 8260', datetime.time(3, 0), datetime.time(4, 0), datetime.time(1, 0), 'OFF - Desligamento/Shutdown', 'F5', '=SUM(B5:C5)')

# %% [markdown]
# **Visual / Formatação de imagem da planilha**

# %%
from openpyxl.styles import Font,PatternFill
a1 = sheet['A1']
ft = Font(color="00FFFFFF", size=14, bold=True)
fl = PatternFill("solid", fgColor="00660066")
a1.font = ft
a1.fill = fl
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-275da695739b> in <module>()
#       7
#       8 for n in sheet.iter_rows(max_row=1):
# ----> 9   n.font = ft
#      10   n.fill = fl
#
# AttributeError: 'tuple' object has no attribute 'font'

# %%
workbook.save(filename='helloworld.xlsx')
